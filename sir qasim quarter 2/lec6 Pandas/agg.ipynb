# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
display(df.SibSp.mean())
display(df.Parch.min())
display(df.Parch.max())
# Out:
# 0.5230078563411896
# 0
# 6

# %%
display(df[['Age','Fare']].median())
display(df[['Age','Fare']].mean())
# Out:
# Age     28.0000
# Fare    14.4542
# dtype: float64
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %%
display(df[['Age','Fare']].describe())
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
df.agg({'Age':['sum','min','median','skew'],'Fare':['min','median','skew','max']})
# Out:
#                  Age        Fare
# sum     21205.170000         NaN
# min         0.420000    0.000000
# median     28.000000   14.454200
# skew        0.389108    4.787317
# max              NaN  512.329200

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
aa=df[['Sex','Age']].groupby('Sex')
display(aa.groups)
display(aa.get_group('female').agg('min'))
# Out:
# {'female': [1, 2, 3, 8, 9, 10, 11, 14, 15, 18, 19, 22, 24, 25, 28, 31, 32, 38, 39, 40, 41, 43, 44, 47, 49, 52, 53, 56, 58, 61, 66, 68, 71, 79, 82, 84, 85, 88, 98, 100, 106, 109, 111, 113, 114, 119, 123, 128, 132, 133, 136, 140, 141, 142, 147, 151, 156, 161, 166, 167, 172, 177, 180, 184, 186, 190, 192, 194, 195, 198, 199, 205, 208, 211, 215, 216, 218, 229, 230, 233, 235, 237, 240, 241, 246, 247, 251, 254, 255, 256, 257, 258, 259, 264, 268, 269, 272, 274, 275, 276, ...], 'male': [0, 4, 5, 6, 7, 12, 13, 16, 17, 20, 21, 23, 26, 27, 29, 30, 33, 34, 35, 36, 37, 42, 45, 46, 48, 50, 51, 54, 55, 57, 59, 60, 62, 63, 64, 65, 67, 69, 70, 72, 73, 74, 75, 76, 77, 78, 80, 81, 83, 86, 87, 89, 90, 91, 92, 93, 94, 95, 96, 97, 99, 101, 102, 103, 104, 105, 107, 108, 110, 112, 115, 116, 117, 118, 120, 121, 122, 124, 125, 126, 127, 129, 130, 131, 134, 135, 137, 138, 139, 143, 144, 145, 146, 148, 149, 150, 152, 153, 154, 155, ...]}
# Sex    female
# Age      0.75
# dtype: object

# %%
display(df[['Age','Sex']].value_counts())

display(df.groupby('Sex').agg('mean'))
display(df[['Age','Sex']].groupby('Sex').agg('mean'))
display(df[['Age','Sex']].groupby('Sex').agg('max'))
display(df[['Age','Sex']].groupby('Sex').agg({'Age':['min','max']}))
# Out:
# Age   Sex
# 19.0  male      18
# 25.0  male      18
# 28.0  male      18
# 21.0  male      17
# 24.0  female    16
#                 ..
# 32.5  male       1
# 34.5  male       1
# 36.5  male       1
# 37.0  female     1
# 80.0  male       1
# Length: 145, dtype: int64
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893
#               Age
# Sex
# female  27.915709
# male    30.726645
#          Age
# Sex
# female  63.0
# male    80.0
#          Age
#          min   max
# Sex
# female  0.75  63.0
# male    0.42  80.0

# %%
display(df[['Sex','Age']].groupby('Sex').agg({'Age':['mean','median','max','min']}))
# Out:
#               Age
#              mean median   max   min
# Sex
# female  27.915709   27.0  63.0  0.75
# male    30.726645   29.0  80.0  0.42

# %%
bb=df.groupby('Sex')

# %%
bb_groups=bb.groups
display(bb_groups)
# Out:
# {'female': [1, 2, 3, 8, 9, 10, 11, 14, 15, 18, 19, 22, 24, 25, 28, 31, 32, 38, 39, 40, 41, 43, 44, 47, 49, 52, 53, 56, 58, 61, 66, 68, 71, 79, 82, 84, 85, 88, 98, 100, 106, 109, 111, 113, 114, 119, 123, 128, 132, 133, 136, 140, 141, 142, 147, 151, 156, 161, 166, 167, 172, 177, 180, 184, 186, 190, 192, 194, 195, 198, 199, 205, 208, 211, 215, 216, 218, 229, 230, 233, 235, 237, 240, 241, 246, 247, 251, 254, 255, 256, 257, 258, 259, 264, 268, 269, 272, 274, 275, 276, ...], 'male': [0, 4, 5, 6, 7, 12, 13, 16, 17, 20, 21, 23, 26, 27, 29, 30, 33, 34, 35, 36, 37, 42, 45, 46, 48, 50, 51, 54, 55, 57, 59, 60, 62, 63, 64, 65, 67, 69, 70, 72, 73, 74, 75, 76, 77, 78, 80, 81, 83, 86, 87, 89, 90, 91, 92, 93, 94, 95, 96, 97, 99, 101, 102, 103, 104, 105, 107, 108, 110, 112, 115, 116, 117, 118, 120, 121, 122, 124, 125, 126, 127, 129, 130, 131, 134, 135, 137, 138, 139, 143, 144, 145, 146, 148, 149, 150, 152, 153, 154, 155, ...]}

# %%
pd.DataFrame(bb_groups)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 pd.DataFrame(bb_groups)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
# ...

# %%
pd.DataFrame(bb)
# Out:
#         0                                                  1
# 0  female       PassengerId  Survived  Pclass  \
# 1       ...
# 1    male       PassengerId  Survived  Pclass            ...

# %%
pd.DataFrame(bb)[1]
# Out:
# 0         PassengerId  Survived  Pclass  \
# 1       ...
# 1         PassengerId  Survived  Pclass            ...
# Name: 1, dtype: object

# %%
pd.DataFrame(bb)[1].values
# Out:
# array([     PassengerId  Survived  Pclass  \
#        1              2         1       1
#        2              3         1       3
#        3              4         1       1
#        8              9         1       3
#        9             10         1       2
#        ..           ...       ...     ...
#        880          881         1       2
#        882          883         0       3
#        885          886         0       3
#        887          888         1       1
#        888          889         0       3
#
#                                                          Name     Sex   Age  SibSp  \
#        1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#        2                               Heikkinen, Miss. Laina  female  26.0      0
#        3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#        8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ...

# %%
pd.DataFrame(bb)[1].values[0] #records of female
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.DataFrame(bb)[1].values[1] #records of male
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
aaa=df.groupby(['Sex','Pclass'])
aaa

# %%
abccc=pd.DataFrame(aaa)
abccc
# Out:
#              0                                                  1
# 0  (female, 1)       PassengerId  Survived  Pclass  \
# 1       ...
# 1  (female, 2)       PassengerId  Survived  Pclass  \
# 9       ...
# 2  (female, 3)       PassengerId  Survived  Pclass  \
# 2       ...
# 3    (male, 1)       PassengerId  Survived  Pclass            ...
# 4    (male, 2)       PassengerId  Survived  Pclass            ...
# 5    (male, 3)       PassengerId  Survived  Pclass            ...

# %%
abccc[1]
# Out:
# 0         PassengerId  Survived  Pclass  \
# 1       ...
# 1         PassengerId  Survived  Pclass  \
# 9       ...
# 2         PassengerId  Survived  Pclass  \
# 2       ...
# 3         PassengerId  Survived  Pclass            ...
# 4         PassengerId  Survived  Pclass            ...
# 5         PassengerId  Survived  Pclass            ...
# Name: 1, dtype: object

# %%
abccc[1].values
# Out:
# array([     PassengerId  Survived  Pclass  \
#        1              2         1       1
#        3              4         1       1
#        11            12         1       1
#        31            32         1       1
#        52            53         1       1
#        ..           ...       ...     ...
#        856          857         1       1
#        862          863         1       1
#        871          872         1       1
#        879          880         1       1
#        887          888         1       1
#
#                                                          Name     Sex   Age  SibSp  \
#        1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#        3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#        11                            Bonnell, Miss. Elizabeth  female  58.0      0
#        31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ...

# %%
abccc[1].values[2]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 14            15         0       3
# 18            19         0       3
# ..           ...       ...     ...
# 863          864         0       3
# 875          876         1       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
aaa.groups
# Out:
# {('female', 1): [1, 3, 11, 31, 52, 61, 88, 136, 151, 166, 177, 194, 195, 215, 218, 230, 256, 257, 258, 268, 269, 275, 290, 291, 297, 299, 306, 307, 309, 310, 311, 318, 319, 325, 329, 334, 337, 341, 356, 366, 369, 375, 380, 383, 393, 412, 435, 457, 486, 496, 498, 504, 513, 520, 523, 537, 539, 540, 556, 558, 571, 577, 581, 585, 591, 609, 627, 641, 669, 689, 700, 708, 710, 716, 730, 742, 759, 763, 765, 779, 781, 796, 809, 820, 829, 835, 842, 849, 853, 856, 862, 871, 879, 887], ('female', 2): [9, 15, 41, 43, 53, 56, 58, 66, 84, 98, 123, 133, 161, 190, 199, 211, 237, 247, 259, 272, 303, 312, 316, 322, 323, 327, 345, 346, 357, 387, 389, 399, 416, 417, 426, 427, 432, 437, 440, 443, 446, 458, 472, 473, 506, 516, 518, 526, 530, 535, 546, 576, 580, 596, 600, 608, 615, 618, 635, 651, 670, 706, 717, 720, 726, 747, 750, 754, 772, 774, 801, 854, 865, 866, 874, 880], ('female', 3): [2, 8, 10, 14, 18, 19, 22, 24, 25, 28, 32, 38, 39, 40, 44, 47, 49, 68, 71, 79, 82, 85, 100, 106, 109, 111, 113, 114, 1
# ...

# %%
aaa.get_group(('female', 1))
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby(['Sex','Age']).size()
# Out:
# Sex     Age
# female  0.75     2
#         1.00     2
#         2.00     6
#         3.00     2
#         4.00     5
#                 ..
# male    70.00    2
#         70.50    1
#         71.00    2
#         74.00    1
#         80.00    1
# Length: 145, dtype: int64

# %%
df.groupby(['Sex','Age'])['Fare'].mean()
# Out:
# Sex     Age
# female  0.75     19.258300
#         1.00     13.437500
#         2.00     43.245833
#         3.00     31.327100
#         4.00     22.828340
#                    ...
# male    70.00    40.750000
#         70.50     7.750000
#         71.00    42.079200
#         74.00     7.775000
#         80.00    30.000000
# Name: Fare, Length: 145, dtype: float64

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Sex'].value_counts(dropna=False)
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
df['Age'].value_counts(dropna=False)
# Out:
# NaN      177
# 24.00     30
# 22.00     27
# 18.00     26
# 28.00     25
#         ...
# 36.50      1
# 55.50      1
# 0.92       1
# 23.50      1
# 74.00      1
# Name: Age, Length: 89, dtype: int64

# %%
df.groupby('Pclass').groups
# Out:
# {1: [1, 3, 6, 11, 23, 27, 30, 31, 34, 35, 52, 54, 55, 61, 62, 64, 83, 88, 92, 96, 97, 102, 110, 118, 124, 136, 137, 139, 151, 155, 166, 168, 170, 174, 177, 185, 187, 194, 195, 209, 215, 218, 224, 230, 245, 248, 252, 256, 257, 258, 262, 263, 268, 269, 270, 273, 275, 284, 290, 291, 295, 297, 298, 299, 305, 306, 307, 309, 310, 311, 318, 319, 325, 329, 331, 332, 334, 336, 337, 339, 341, 351, 356, 366, 369, 370, 373, 375, 377, 380, 383, 390, 393, 412, 430, 434, 435, 438, 445, 447, ...], 2: [9, 15, 17, 20, 21, 33, 41, 43, 53, 56, 58, 66, 70, 72, 78, 84, 98, 99, 117, 120, 122, 123, 133, 134, 135, 144, 145, 148, 149, 150, 161, 178, 181, 183, 190, 191, 193, 199, 211, 213, 217, 219, 221, 226, 228, 232, 234, 236, 237, 238, 239, 242, 247, 249, 259, 265, 272, 277, 288, 292, 303, 308, 312, 314, 316, 317, 322, 323, 327, 340, 342, 343, 344, 345, 346, 357, 361, 385, 387, 389, 397, 398, 399, 405, 407, 413, 416, 417, 418, 426, 427, 432, 437, 439, 440, 443, 446, 450, 458, 463, ...], 3: [0, 2, 4, 5, 7, 8
# ...

# %%
pd.DataFrame(df.groupby('Pclass'))
# Out:
#    0                                                  1
# 0  1       PassengerId  Survived  Pclass  \
# 1       ...
# 1  2       PassengerId  Survived  Pclass  \
# 9       ...
# 2  3       PassengerId  Survived  Pclass            ...

# %%
pd.DataFrame(df.groupby('Pclass'))[1].values[1]
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# 20            21         0       2
# 21            22         1       2
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1      0
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 17                   Williams, Mr. Charles Eugene    male   NaN      0      0
# 20                           Fynney, Mr. Joseph J    male  35.0      0      0
# 21                          Beesley, Mr. Lawrence    male  34.0      0      0
# ...

# %%
df.groupby('Pclass').size()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# dtype: int64

# %%
df.groupby('Pclass')['Pclass'].mean()
# Out:
# Pclass
# 1    1.0
# 2    2.0
# 3    3.0
# Name: Pclass, dtype: float64

# %%
df.groupby('Pclass')['Pclass'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
aa=df.groupby(['Sex'])[["PassengerId","Survived"]]

# %%
aa.groups
# Out:
# {'female': [1, 2, 3, 8, 9, 10, 11, 14, 15, 18, 19, 22, 24, 25, 28, 31, 32, 38, 39, 40, 41, 43, 44, 47, 49, 52, 53, 56, 58, 61, 66, 68, 71, 79, 82, 84, 85, 88, 98, 100, 106, 109, 111, 113, 114, 119, 123, 128, 132, 133, 136, 140, 141, 142, 147, 151, 156, 161, 166, 167, 172, 177, 180, 184, 186, 190, 192, 194, 195, 198, 199, 205, 208, 211, 215, 216, 218, 229, 230, 233, 235, 237, 240, 241, 246, 247, 251, 254, 255, 256, 257, 258, 259, 264, 268, 269, 272, 274, 275, 276, ...], 'male': [0, 4, 5, 6, 7, 12, 13, 16, 17, 20, 21, 23, 26, 27, 29, 30, 33, 34, 35, 36, 37, 42, 45, 46, 48, 50, 51, 54, 55, 57, 59, 60, 62, 63, 64, 65, 67, 69, 70, 72, 73, 74, 75, 76, 77, 78, 80, 81, 83, 86, 87, 89, 90, 91, 92, 93, 94, 95, 96, 97, 99, 101, 102, 103, 104, 105, 107, 108, 110, 112, 115, 116, 117, 118, 120, 121, 122, 124, 125, 126, 127, 129, 130, 131, 134, 135, 137, 138, 139, 143, 144, 145, 146, 148, 149, 150, 152, 153, 154, 155, ...]}

# %%
aa.get_group('female')
# Out:
#      PassengerId  Survived
# 1              2         1
# 2              3         1
# 3              4         1
# 8              9         1
# 9             10         1
# ..           ...       ...
# 880          881         1
# 882          883         0
# 885          886         0
# 887          888         1
# 888          889         0
#
# [314 rows x 2 columns]

# %%
aa=df.groupby(['Sex'])[["PassengerId","Survived"]].agg('mean')

# %%
aa
# Out:
#         PassengerId  Survived
# Sex
# female   431.028662  0.742038
# male     454.147314  0.188908

# %%
df.groupby(['Sex']).get_group("male").head()
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0            1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4            5         0       3        Allen, Mr. William Henry  male  35.0
# 5            6         0       3                Moran, Mr. James  male   NaN
# 6            7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7            8         0       3  Palsson, Master. Gosta Leonard  male   2.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S

# %%
df.groupby('Sex').apply(lambda x:x[['Pclass','Fare']].apply(lambda y:y[0]+y[1],axis=1))
# Out:
# Sex
# female  1      72.2833
#         2      10.9250
#         3      54.1000
#         8      14.1333
#         9      32.0708
#                 ...
# male    883    12.5000
#         884    10.0500
#         886    15.0000
#         889    31.0000
#         890    10.7500
# Length: 891, dtype: float64

# %%
df.groupby(['Sex']).apply(lambda x:x[["Pclass","Fare"]].apply(lambda y:y[0]+y[1], axis=1))
# Out:
# Sex
# female  1      72.2833
#         2      10.9250
#         3      54.1000
#         8      14.1333
#         9      32.0708
#                 ...
# male    883    12.5000
#         884    10.0500
#         886    15.0000
#         889    31.0000
#         890    10.7500
# Length: 891, dtype: float64
