# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
tit=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tit.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
tit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
tit['Age'].value_counts(dropna=False)
# Out:
# NaN      177
# 24.00     30
# 22.00     27
# 18.00     26
# 28.00     25
#         ...
# 36.50      1
# 55.50      1
# 0.92       1
# 23.50      1
# 74.00      1
# Name: Age, Length: 89, dtype: int64

# %%
(tit['Age']>=15).sum()
# Out:
# 636

# %%
(tit['Age']<=40).sum()
# Out:
# 564

# %%
((tit['Age']>=15) & (tit['Age']<=40)).sum()
# Out:
# 486

# %%
tit['Age'][(tit['Age']>=15) & (tit['Age']<=40)]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 486, dtype: float64

# %%
tit[(tit['Age']>=15) & (tit['Age']<=40)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1=tit[tit['Age'].isin([20,22])]
display(df1.head())
display(len(df1))
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0             1         0       3         Braund, Mr. Owen Harris  male  22.0
# 12           13         0       3  Saundercock, Mr. William Henry  male  20.0
# 60           61         0       3           Sirayanian, Mr. Orsen  male  22.0
# 80           81         0       3            Waelens, Mr. Achille  male  22.0
# 91           92         0       3      Andreasson, Mr. Paul Edvin  male  20.0
#
#     SibSp  Parch     Ticket    Fare Cabin Embarked
# 0       1      0  A/5 21171  7.2500   NaN        S
# 12      0      0  A/5. 2151  8.0500   NaN        S
# 60      0      0       2669  7.2292   NaN        C
# 80      0      0     345767  9.0000   NaN        S
# 91      0      0     347466  7.8542   NaN        S
# 42

# %%
r=[]
for i in tit['Age']:
    if(i==20):
        r.append(i)
    elif(i==22):
        r.append(i)
print(r)
print(len(r))
# Out:
# [22.0, 20.0, 22.0, 22.0, 20.0, 22.0, 20.0, 20.0, 22.0, 22.0, 22.0, 22.0, 22.0, 22.0, 22.0, 22.0, 22.0, 22.0, 22.0, 22.0, 20.0, 22.0, 20.0, 20.0, 22.0, 22.0, 22.0, 22.0, 22.0, 22.0, 22.0, 22.0, 20.0, 20.0, 20.0, 20.0, 22.0, 20.0, 20.0, 20.0, 20.0, 22.0]
# 42

# %%
[i for i in tit['Age'] if(i==20 or i==22)]
# Out:
# [22.0,
#  20.0,
#  22.0,
#  22.0,
#  20.0,
#  22.0,
#  20.0,
#  20.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  20.0,
#  22.0,
#  20.0,
#  20.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  20.0,
#  20.0,
#  20.0,
#  20.0,
#  22.0,
#  20.0,
#  20.0,
#  20.0,
#  20.0,
#  22.0]

# %%
tit['Age'][((tit['Age']==20) | (tit['Age']==22))]
# Out:
# 0      22.0
# 12     20.0
# 60     22.0
# 80     22.0
# 91     20.0
# 112    22.0
# 113    20.0
# 131    20.0
# 141    22.0
# 151    22.0
# 212    22.0
# 225    22.0
# 243    22.0
# 287    22.0
# 289    22.0
# 320    22.0
# 323    22.0
# 356    22.0
# 373    22.0
# 376    22.0
# 378    20.0
# 395    22.0
# 404    20.0
# 441    20.0
# 474    22.0
# 478    22.0
# 521    22.0
# 539    22.0
# 553    22.0
# 554    22.0
# 588    22.0
# 608    22.0
# 622    20.0
# 640    20.0
# 664    20.0
# 682    20.0
# 708    22.0
# 725    20.0
# 762    20.0
# 840    20.0
# 876    20.0
# 882    22.0
# Name: Age, dtype: float64

# %%
display((tit['Name']=='Braund, Mr. Owen Harris').sum())
a=tit[tit['Name']=='Braund, Mr. Owen Harris'].copy()
display(a)
display(len(a))
# Out:
# 1
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S
# 1

# %%
tit[tit['Name'].isin(['Braund, Mr. Owen Harris','Heikkinen, Miss. Laina'])]
# Out:
#    PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 0            1         0       3  Braund, Mr. Owen Harris    male  22.0
# 2            3         1       3   Heikkinen, Miss. Laina  female  26.0
#
#    SibSp  Parch            Ticket   Fare Cabin Embarked
# 0      1      0         A/5 21171  7.250   NaN        S
# 2      0      0  STON/O2. 3101282  7.925   NaN        S

# %%
df2=tit.copy()
df2=tit[(tit['Age']>=25) & (tit['Age']<=30)]
display(df2)
display(tit.info())
display(len(df2))
display(tit['Age'].isnull().sum())
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 23            24         1       1
# 34            35         0       1
# 41            42         0       2
# ..           ...       ...     ...
# 880          881         1       2
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 34                             Meyer, Mr. Edgar Joseph    male  28.0      1
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
(131/714)*100 #approx 18 perc of the peaple are at the age of between 25 to 30
# Out:
# 18.34733893557423

# %%
a=[2,3,6,8,5,9,11]
for i in a:
    if(i%2==0 and i%3==0):
        print(i)
# Out:
# 6

# %%
a=[2,3,6,8,5,9,11]
for i in a:
    if(i%2==0 or i%3==0):
        print(i)
# Out:
# 2
# 3
# 6
# 8
# 9

# %%
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
a=tit['Name'].str.lower()
b=a.str.contains('mr')
display(b.sum())
display(b)
display(tit[b])
# tit.Name.str.lower().str.contains("mr.")
display(tit.info())
# Out:
# 647
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Name, Length: 891, dtype: bool
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
aa=tit.copy()
aa=tit[(tit['Name'].str.lower().str.contains('mr.')) & (~tit['Name'].str.lower().str.contains('mrs.'))]
display(aa)
len(aa) #this dataset contain the data of 'Male'
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
display(tit[(tit['Name'].str.lower().str.contains('mrs.'))])
display(tit['Name'].str.lower().str.contains('mrs.').sum())
display(tit['Sex'].value_counts())
display(tit['Sex'].unique())
display(tit['Age'].value_counts(dropna=False))
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 15            16         1       2
# ..           ...       ...     ...
# 871          872         1       1
# 874          875         1       2
# 879          880         1       1
# 880          881         1       2
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tit['Age'].isnull().sum()
# Out:
# 177

# %%
tit['Age'].notnull().sum()
# Out:
# 714

# %%
display((~tit['Age'].isnull()).sum())
(~tit['Age'].notnull()).sum()
# Out:
# 714
# 177

# %%
tit.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
tit.iloc[2:10,2:6]
# Out:
#    Pclass                                               Name     Sex   Age
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
# 5       3                                   Moran, Mr. James    male   NaN
# 6       1                            McCarthy, Mr. Timothy J    male  54.0
# 7       3                     Palsson, Master. Gosta Leonard    male   2.0
# 8       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9       2                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
tit[2:6]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q

# %%
tit.iloc[2:5,:]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#              Ticket    Fare Cabin Embarked
# 2  STON/O2. 3101282   7.925   NaN        S
# 3            113803  53.100  C123        S
# 4            373450   8.050   NaN        S

# %%
tit.iloc[2:9,-3:]
# Out:
#       Fare Cabin Embarked
# 2   7.9250   NaN        S
# 3  53.1000  C123        S
# 4   8.0500   NaN        S
# 5   8.4583   NaN        Q
# 6  51.8625   E46        S
# 7  21.0750   NaN        S
# 8  11.1333   NaN        S

# %%
tit.loc[2:10,'Ticket':'Embarked']
# Out:
#               Ticket     Fare Cabin Embarked
# 2   STON/O2. 3101282   7.9250   NaN        S
# 3             113803  53.1000  C123        S
# 4             373450   8.0500   NaN        S
# 5             330877   8.4583   NaN        Q
# 6              17463  51.8625   E46        S
# 7             349909  21.0750   NaN        S
# 8             347742  11.1333   NaN        S
# 9             237736  30.0708   NaN        C
# 10           PP 9549  16.7000    G6        S

# %%
tit.iloc[2:11,2]=23323
display(tit)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1   23323
# 3              4         1   23323
# 4              5         0   23323
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tit.plot()
# Out:
# <AxesSubplot:>

# %%
display(tit.plot.box())
# Out:
# <AxesSubplot:>

# %%
display(tit['Age'].plot())
# Out:
# <AxesSubplot:>

# %%
display(tit['Age'].plot.box())
# Out:
# <AxesSubplot:>

# %%
display(tit.plot.scatter(x='Age',y='Parch',alpha=0.5))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Parch'>

# %%
axs = tit.plot.area(figsize=(12, 4), subplots=True)
# plt.show()

# %%
fig, axs = plt.subplots(figsize=(12, 4))

tit.plot.area(ax=axs)

axs.set_ylabel("titanic_data")

fig.savefig("no2_concentrations.png")

plt.show()
